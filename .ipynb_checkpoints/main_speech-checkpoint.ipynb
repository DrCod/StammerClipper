# %%
import speech_recognition as sr
from requests_toolbelt import MultipartEncoder
import requests
import simplejson as json
from pydub import AudioSegment
import librosa
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import re
import operator
import os
import shutil

# %%
from os.path import join
from praatio import tgio
import glob

tgrids = sorted(glob.glob('AllAudioWav/generated_textgrids/*.TextGrid'))

wav_files = sorted(glob.glob('AllAudioWav/*.wav'))

fnListZipped = zip(tgrids, wav_files)

fnList = [(tg,wav) for tg, wav in fnListZipped]


outputList = []

for tgName,wavName in fnList:
    tg = tgio.openTextgrid(tgName)
    # 2 - extract all the words and their corresponding timestamps
    targetTier = tg.tierDict['words']
    outputList+=(wavName,targetTier.entryList)

outputList
# Out:
# ['AllAudioWav/F_0050_10y9m_1.wav',
#  [Interval(start=0.0, end=0.7656736853652767, label='errrm'),
#   Interval(start=0.7656736853652767, end=1.320377844383865, label='as'),
#   Interval(start=1.320377844383865, end=1.5382973354268819, label='we'),
#   Interval(start=1.5382973354268819, end=1.5422595079913004, label='start'),
#   Interval(start=1.5422595079913004, end=1.863195485709198, label='start'),
#   Interval(start=1.863195485709198, end=2.164320600605003, label='our'),
#   Interval(start=2.164320600605003, end=2.544689166789178, label='first'),
#   Interval(start=2.544689166789178, end=3.832395250225187, label='thursday'),
#   Interval(start=3.832395250225187, end=4.207276212321996, label='we'),
#   Interval(start=4.207276212321996, end=4.575758260812916, label='went'),
#   Interval(start=4.575758260812916, end=4.829337304935699, label='ert'),
#   Interval(start=4.829337304935699, end=5.027445933156623, label='to'),
#   Interval(start=5.027445933156623, end=5.257251941892895, label='my'),
#   Interval(start=5.257251941892895, end=6.262985505711321, label="nanny's"),
#   Interval(start=6.262985505711321, end=7.20994474860734, label='pause'),
#   Interval(start=7.20994474860734, end=7.545039434902161, label='cuz'),
#   Interval(start=7.545039434902161, end=7.818429341847036, label='my'),
#   Interval(start=7.818429341847036, end=8.30577656727051, label='parents'),
#   Interval(start=8.30577656727051, end=8.495960850362598, label='were'),
#   Interval(start=8.495960850362598, end=8.662372098068174, label='going'),
#   Interval(start=8.662372098068174, end=9.260660155295366, label='to'),
#   Interval(start=9.268584500424202, end=9.43499574812978, label='a'),
#   Interval(start=9.43499574812978, end=10.864681709428332, label='friends'),
#   Interval(start=10.864681709428332, end=14.619460486044566, label='stammered_wedding'),
#   Interval(start=14.619460486044566, end=16.144238655801818, label='and'),
#   Interval(start=16.144238655801818, end=16.461750390793462, label='then'),
#   Interval(start=16.461750390793462, end=16.691556399529734, label='we'),
#   Interval(start=16.691556399529734, end=16.83023243928438, label='went'),
#   Interval(start=16.83023243928438, end=17.38889877086739, label='home'),
#   Interval(start=17.38889877086739, end=17.555310018572964, label='on'),
#   Interval(start=17.555310018572964, end=18.533966641984332, label='saturday'),
#   Interval(start=18.533966641984332, end=19.253392067027743, label='we'),
#   Interval(start=19.253392067027743, end=19.55055500935913, label="didnt't"),
#   Interval(start=19.55055500935913, end=20.033940062218186, label='do'),
#   Interval(start=20.033940062218186, end=20.7867528494577, label='much'),
#   Interval(start=20.7867528494577, end=20.94631574553607, label='we'),
#   Interval(start=20.94631574553607, end=21.243478687867455, label='just'),
#   Interval(start=21.243478687867455, end=21.5961120461007, label='they'),
#   Interval(start=21.5961120461007, end=22.043837545879992, label="didn't"),
#   Interval(start=22.043837545879992, end=22.46779001027277, label='because'),
#   Interval(start=22.46779001027277, end=22.657974293364855, label='the'),
#   Interval(start=22.657974293364855, end=23.272111040849722, label='rained'),
#   Interval(start=23.272111040849722, end=23.664904054565323, label='pause'),
#   Interval(start=23.664904054565323, end=24.95657231056575, label='for'),
#   Interval(start=24.95657231056575, end=25.75024736710888, label='i think'),
#   Interval(start=25.75024736710888, end=25.952318167894223, label='cuz'),
#   Interval(start=25.952318167894223, end=26.19797286688817, label="it's on"),
#   Interval(start=26.19797286688817, end=26.360421942029326, label='the'),
#   Interval(start=26.360421942029326, end=27.37473811852046, label='sunday'),
#   Interval(start=27.37473811852046, end=28.34188160391893, label='no'),
#   Interval(start=28.34188160391893, end=29.169975669882394, label='thursday'),
#   Interval(start=29.169975669882394, end=29.379970815796575, label='we'),
#   Interval(start=29.383932988360993, end=29.70486896607889, label='went'),
#   Interval(start=29.70486896607889, end=30.350703094079105, label='to'),
#   Interval(start=30.350703094079105, end=31.046520033893813, label='this'),
#   Interval(start=31.046520033893813, end=31.797807456523035, label='train'),
#   Interval(start=31.797807456523035, end=34.068132335934834, label='stammered_museum'),
#   Interval(start=34.068132335934834, end=34.37858688977672, label='pause'),
#   Interval(start=34.37858688977672, end=35.24630268138437, label='and it was'),
#   Interval(start=35.24630268138437, end=36.46268965866085, label='stammered_okay'),
#   Interval(start=36.46268965866085, end=36.88067177142648, label='but'),
#   Interval(start=36.88067177142648, end=37.364056824285534, label='it'),
#   Interval(start=37.364056824285534, end=37.60971152327948, label='was'),
#   Interval(start=37.60971152327948, end=37.855366222273425, label='bit'),
#   Interval(start=37.855366222273425, end=39.412006322703824, label='boring'),
#   Interval(start=39.412006322703824, end=41.09027523330632, label='and'),
#   Interval(start=41.09027523330632, end=41.97850443464467, label='and'),
#   Interval(start=41.97850443464467, end=42.24793216902513, label='then'),
#   Interval(start=42.24793216902513, end=43.12357230576162, label='cuz'),
#   Interval(start=43.12357230576162, end=44.67279001276786, label='when an'),
#   Interval(start=44.67279001276786, end=45.92087437055969, label='play'),
#   Interval(start=45.92087437055969, end=46.66473109853348, label='balls'),
#   Interval(start=46.66473109853348, end=47.67372428800771, label='we'),
#   Interval(start=47.67372428800771, end=48.3354071062656, label='went'),
#   Interval(start=48.3354071062656, end=48.91116260485307, label='and'),
#   Interval(start=48.91116260485307, end=49.402472002840966, label='that'),
#   Interval(start=49.402472002840966, end=49.953213989295136, label='paint'),
#   Interval(start=49.953213989295136, end=50.56735073678, label='this'),
#   Interval(start=50.56735073678, end=51.01507623655929, label='whole'),
#   Interval(start=51.01507623655929, end=51.904875081872696, label='for about'),
#   Interval(start=51.904875081872696, end=52.293167993185705, label='half'),
#   Interval(start=53.91369657203287, end=55.34268005333544, label='pause'),
#   Interval(start=55.34268005333544, end=55.68380027355579, label='very'),
#   Interval(start=55.68380027355579, end=56.41680219797321, label='exciting'),
#   Interval(start=56.41680219797321, end=57.054382880529, label='and'),
#   Interval(start=57.054382880529, end=57.584984836932804, label='then'),
#   Interval(start=57.584984836932804, end=58.298175898528136, label='sunday'),
#   Interval(start=58.298175898528136, end=59.058913030896484, label='pause'),
#   Interval(start=59.058913030896484, end=59.22928645116648, label='went'),
#   Interval(start=59.22928645116648, end=59.537139646896435, label='went'),
#   Interval(start=59.537139646896435, end=59.999517572638716, label='on'),
#   Interval(start=59.999517572638716, end=60.55818390422173, label='distinct'),
#   Interval(start=60.585919112172654, end=61.57646225327728, label='train'),
#   Interval(start=61.57646225327728, end=63.33397689019832, label='pause'),
#   Interval(start=63.33397689019832, end=63.56915016531626, label='and'),
#   Interval(start=63.56915016531626, end=64.44479030205275, label='back'),
#   Interval(start=64.44479030205275, end=65.68495031471575, label='we'),
#   Interval(start=65.68495031471575, end=67.22264664939048, label='we'),
#   Interval(start=67.22264664939048, end=68.09502716047115, label='it was okay'),
#   Interval(start=68.09502716047115, end=68.41596313818906, label='but'),
#   Interval(start=68.41596313818906, end=68.92246295889075, label='it'),
#   Interval(start=70.27356380335746, end=71.11701284219252, label='stammered'),
#   Interval(start=73.03334354891858, end=73.74810425448895, label='and'),
#   Interval(start=73.74810425448895, end=74.66336611686962, label='the'),
#   Interval(start=74.66336611686962, end=75.87975309414611, label='pause'),
#   Interval(start=75.87975309414611, end=76.44378669211076, label='and'),
#   Interval(start=76.44378669211076, end=77.46260297100449, label='the_prolonged'),
#   Interval(start=77.46260297100449, end=78.03315582028075, label='was'),
#   Interval(start=78.03315582028075, end=78.73049819161841, label='erm'),
#   Interval(start=78.73049819161841, end=79.41942250044116, label='floods'),
#   Interval(start=79.41942250044116, end=80.48920909283416, label='in the'),
#   Interval(start=80.48920909283416, end=82.07374901828595, label='nearby_stammered'),
#   Interval(start=82.07374901828595, end=82.88756403796677, label='pause'),
#   Interval(start=82.88756403796677, end=83.44623036954978, label='and'),
#   Interval(start=83.44623036954978, end=83.95772401004012, label='there'),
#   Interval(start=83.95772401004012, end=84.3579034390464, label='we'),
#   Interval(start=84.3579034390464, end=84.8729858724208, label='stayed'),
#   Interval(start=84.8729858724208, end=85.72485297377078, label='stayed in'),
#   Interval(start=85.72485297377078, end=87.25289076918382, label='and'),
#   Interval(start=87.25289076918382, end=87.70821144686369, label='one of'),
#   Interval(start=87.70821144686369, end=87.8587740043116, label='the'),
#   Interval(start=89.82401159626316, end=92.32831348649819, label='it was just'),
#   Interval(start=92.32831348649819, end=94.2710185867227, label='stayed_stammered'),
#   Interval(start=94.2710185867227, end=94.55270621847677, label='and then'),
#   Interval(start=94.55270621847677, end=94.94892347491862, label='play'),
#   Interval(start=94.94892347491862, end=95.45211939059976, label='games'),
#   Interval(start=95.45211939059976, end=96.13757524424416, label='and stuff'),
#   Interval(start=96.13757524424416, end=96.48075882582562, label='but'),
#   Interval(start=96.48075882582562, end=97.24942030332281, label='pause'),
#   Interval(start=97.24942030332281, end=97.65909372143297, label='the'),
#   Interval(start=97.65909372143297, end=98.24945743353132, label='day'),
#   Interval(start=98.24945743353132, end=99.79747064192426, label='that we'),
#   Interval(start=99.79747064192426, end=100.59027860140098, label='picked'),
#   Interval(start=100.59027860140098, end=101.11328537990423, label='up'),
#   Interval(start=101.11328537990423, end=101.33516704351166, label='we'),
#   Interval(start=101.33516704351166, end=101.66006519379397, label='went'),
#   Interval(start=101.66006519379397, end=102.13948807408862, label='down'),
#   Interval(start=102.13948807408862, end=103.24097204699696, label='to'),
#   Interval(start=103.24097204699696, end=104.82328399401715, label='to_stammered'),
#   Interval(start=104.82328399401715, end=105.28256684426145, label='this'),
#   Interval(start=105.28256684426145, end=105.67878410070331, label='em'),
#   Interval(start=105.67878410070331, end=106.78167316742886, label='park'),
#   Interval(start=106.78167316742886, end=107.17789042387072, label='and'),
#   Interval(start=107.17789042387072, end=107.56222116261931, label='we'),
#   Interval(start=107.56222116261931, end=108.40773356281551, label='had'),
#   Interval(start=108.40773356281551, end=108.51867439461923, label='a'),
#   Interval(start=108.51867439461923, end=109.06149203594455, label='walk'),
#   Interval(start=109.06149203594455, end=110.02429996909825, label='round'),
#   Interval(start=110.02429996909825, end=110.15505166372407, label='and'),
#   Interval(start=110.15505166372407, end=110.56315543785917, label='then'),
#   Interval(start=110.56315543785917, end=110.78747384250806, label='when'),
#   Interval(start=110.78747384250806, end=110.90237684687621, label='we'),
#   Interval(start=110.90237684687621, end=111.2867075856248, label='came'),
#   Interval(start=111.2867075856248, end=111.51255142179666, label='back'),
#   Interval(start=111.51255142179666, end=111.85726043490106, label='home'),
#   Interval(start=111.85726043490106, end=113.87437964987042, label='mum'),
#   Interval(start=113.87437964987042, end=114.00513134449623, label='and'),
#   Interval(start=114.00513134449623, end=114.2502923261041, label='dad'),
#   Interval(start=114.2502923261041, end=114.48009833484038, label='they were'),
#   Interval(start=114.48009833484038, end=114.77726127717176, label='here'),
#   Interval(start=114.77726127717176, end=115.33196543619036, label='to'),
#   Interval(start=115.33196543619036, end=115.5340362369757, label='take'),
#   Interval(start=115.5340362369757, end=115.75591790058313, label='us'),
#   Interval(start=115.75591790058313, end=116.17987036497591, label='home'),
#   Interval(start=116.17987036497591, end=116.94597476372594, label='and'),
#   Interval(start=116.94597476372594, end=118.0712317720208, label='so'),
#   Interval(start=118.0712317720208, end=118.8333739982064, label='and'),
#   Interval(start=118.8333739982064, end=119.63373285621893, label='so'),
#   Interval(start=119.63373285621893, end=120.5688055814217, label='pause'),
#   Interval(start=120.5688055814217, end=120.79914958690875, label='at'),
#   Interval(start=120.79914958690875, end=121.78969272801338, label='school'),
#   Interval(start=121.78969272801338, end=122.48051584803945, label='lost'),
#   Interval(start=122.48051584803945, end=122.68654882138921, label='and'),
#   Interval(start=122.68654882138921, end=122.95993872833408, label='we'),
#   Interval(start=122.95993872833408, end=123.1144634583464, label='did'),
#   Interval(start=123.1144634583464, end=123.53016241038209, label='about'),
#   Interval(start=123.53016241038209, end=124.23542912684857, label='you'),
#   Interval(start=124.23542912684857, end=127.95525089729368, label='stammered_village'),
#   Interval(start=127.95525089729368, end=128.962372558882, label='whcih'),
#   Interval(start=128.962372558882, end=129.4219845763546, label='is'),
#   Interval(start=129.4219845763546, end=130.39271685463714, label='close'),
#   Interval(start=130.39271685463714, end=131.23220372090773, label='by'),
#   Interval(start=131.23220372090773, end=131.95022405213393, label='and'),
#   Interval(start=131.95022405213393, end=132.16814354317697, label='one'),
#   Interval(start=132.16814354317697, end=132.49304169345928, label='day'),
#   Interval(start=132.49304169345928, end=132.61190687039183, label='we'),
#   Interval(start=132.61190687039183, end=132.99227543657602, label='went')],
#  'AllAudioWav/F_0101_10y4m_1.wav',
#  [Interval(start=0.0, end=0.669682490956392, label='and'),
#   Interval(start=0.669682490956392, end=0.8544304845783847, label='they'),
#   Interval(start=0.8544304845783847, end=1.0676012464499145, label='went'),
#   Interval(start=1.0676012464499145, end=1.6857964558773515, label='off'),
#   Interval(start=3.19220317310283, end=6.055797074243717, label='se'),
#   Interval(start=6.055797074243717, end=6.514729968903372, label='em'),
#   Interval(start=6.514729968903372, end=6.891331648209741, label='in'),
#   Interval(start=6.891331648209741, end=7.040551181519812, label='i'),
#   Interval(start=7.040551181519812, end=7.211087791017037, label='in'),
#   Interval(start=7.211087791017037, end=7.5592667020738675, label='a'),
#   Interval(start=7.5592667020738675, end=8.781445736803974, label='pause'),
#   Interval(start=8.781445736803974, end=9.385429562106642, label='errm'),
#   Interval(start=9.385429562106642, end=12.40134509279962, label='pause'),
#   Interval(start=12.40134509279962, end=12.58489118710245, label='they'),
#   Interval(start=12.58489118710245, end=12.883330253722592, label='had'),
#   Interval(start=12.883330253722592, end=13.892338526581169, label='admission'),
#   Interval(start=13.892338526581169, end=14.872924031190207, label='and'),
#   Interval(start=17.061477186404584, end=18.484816345723083, label='erm'),
#   Interval(start=18.484816345723083, end=19.387239237645893, label='compete'),
#   Interval(start=19.387239237645893, end=19.941483218511873, label='work'),
#   Interval(start=22.975012779490406, end=23.967774003318247, label="I'm"),
#   Interval(start=23.967774003318247, end=24.387009834998924, label='able'),
#   Interval(start=25.125400859827316, end=25.352783005823614, label='quite'),
#   Interval(start=25.352783005823614, end=25.71517330100522, label='far'),
#   Interval(start=25.71517330100522, end=26.219677437434505, label='funny'),
#   Interval(start=30.209606071431143, end=30.621736211049434, label='erm'),
#   Interval(start=30.621736211049434, end=30.913302401534413, label='it'),
#   Interval(start=30.913302401534413, end=31.79440821727007, label='was'),
#   Interval(start=31.79440821727007, end=32.391286350510356, label='about'),
#   Interval(start=32.391286350510356, end=32.94553033137633, label='same'),
#   Interval(start=35.508949975820904, end=36.24794195030888, label='who'),
#   Interval(start=36.24794195030888, end=37.95694343228015, label='if'),
#   Interval(start=39.994241464367455, end=40.690599286481124, label='better'),
#   Interval(start=40.690599286481124, end=41.52196525778009, label='with'),
#   Interval(start=41.52196525778009, end=41.81329863233785, label='perfect'),
#   Interval(start=41.81329863233785, end=42.63045321951205, label='family'),
#   Interval(start=42.63045321951205, end=43.6277512548283, label='and'),
#   Interval(start=45.8518328703546, end=46.944607073812826, label='and'),
#   Interval(start=46.944607073812826, end=47.25725752455774, label='just'),
#   Interval(start=47.25725752455774, end=47.726233200675104, label='trying'),
#   Interval(start=47.726233200675104, end=48.09572918791909, label='to'),
#   Interval(start=48.09572918791909, end=48.3657454862897, label='get'),
#   Interval(start=48.3657454862897, end=48.927095159218055, label='back'),
#   Interval(start=48.927095159218055, end=49.98584327651333, label='to'),
#   Interval(start=54.40468231482702, end=56.31604574561684, label='and'),
#   Interval(start=60.53879476158755, end=60.87012574904306, label='and'),
#   Interval(start=60.87012574904306, end=61.4456868060962, label='someone'),
#   Interval(start=61.4456868060962, end=61.66596326003011, label='had'),
#   Interval(start=61.66596326003011, end=61.77965433302826, label='to'),
#   Interval(start=61.77965433302826, end=62.085199091710784, label='erm'),
#   Interval(start=71.50547618346214, end=78.76539014741039, label='and'),
#   Interval(start=78.76539014741039, end=79.55412196633506, label='still'),
#   Interval(start=79.55412196633506, end=80.63418715981747, label='quite'),
#   Interval(start=80.63418715981747, end=80.96815468674954, label='make'),
#   Interval(start=80.96815468674954, end=81.09605714387246, label='it'),
#   Interval(start=81.09605714387246, end=81.42291897874213, label='to'),
#   Interval(start=81.42291897874213, end=81.80662635011089, label='erm'),
#   Interval(start=81.80662635011089, end=81.99848003579527, label='the'),
#   Interval(start=81.99848003579527, end=82.3892930992264, label='train'),
#   Interval(start=85.28177532538228, end=85.61574285231434, label='until'),
#   Interval(start=85.61574285231434, end=85.87154776656018, label='erm'),
#   Interval(start=85.87154776656018, end=86.15577544905555, label='fat'),
#   Interval(start=86.15577544905555, end=86.37605190298947, label='full'),
#   Interval(start=86.37605190298947, end=86.68870235373439, label='of'),
#   Interval(start=86.68870235373439, end=87.12214956953983, label='the'),
#   Interval(start=87.12214956953983, end=87.42058863615996, label='train'),
#   Interval(start=90.83041940161509, end=91.79786002852438, label='erm'),
#   Interval(start=91.79786002852438, end=92.01813648245829, label='and'),
#   Interval(start=92.01813648245829, end=92.30946985701605, label='to'),
#   Interval(start=92.30946985701605, end=93.14083582831502, label='intend'),
#   Interval(start=95.29386052321748, end=98.13206609344827, label='erm'),
#   Interval(start=109.81922359364674, end=110.13187404439165, label='and'),
#   Interval(start=110.13187404439165, end=110.35215049832556, label='she'),
#   Interval(start=110.35215049832556, end=110.66480094907047, label='was'),
#   Interval(start=110.66480094907047, end=111.16219939343738, label='going'),
#   Interval(start=111.16219939343738, end=111.57432953305567, label='until'),
#   Interval(start=111.57432953305567, end=111.86566290761343, label='they'),
#   Interval(start=111.86566290761343, end=112.22148080148965, label='erm'),
#   Interval(start=114.39582257257925, end=116.68719032883625, label='erm'),
#   Interval(start=122.87504621585383, end=123.30669058268053, label='and'),
#   Interval(start=123.30669058268053, end=123.44880442392822, label='the'),
#   Interval(start=123.44880442392822, end=123.88935733179605, label='erm'),
#   Interval(start=123.88935733179605, end=124.1806907063538, label='at'),
#   Interval(start=124.1806907063538, end=124.76335745546932, label='a'),
#   Interval(start=134.53044647702268, end=135.26943845151064, label='erm'),
#   Interval(start=148.69822773232528, end=149.47274816712516, label='and'),
#   Interval(start=149.47274816712516, end=149.71434169724623, label='she'),
#   Interval(start=149.71434169724623, end=150.17795918367347, label='found')],
#  'AllAudioWav/F_0101_13y1m_1.wav',
#  [Interval(start=0.0, end=1.1154777101010136, label='erm'),
#   Interval(start=1.1154777101010136, end=2.9345348780714016, label='for'),
#   Interval(start=2.9345348780714016, end=4.440941595296879, label='christmas'),
#   Interval(start=4.440941595296879, end=5.407315715781147, label='I'),
#   Interval(start=5.407315715781147, end=5.719966166526057, label='got'),
#   Interval(start=5.719966166526057, end=6.800031360008475, label='back'),
#   Interval(start=6.800031360008475, end=7.396909493248759, label='there'),
#   Interval(start=7.396909493248759, end=8.732779600977013, label='and'),
#   Interval(start=8.732779600977013, end=9.102275588220998, label='I'),
#   Interval(start=9.102275588220998, end=9.557039880213594, label='forgot'),
#   Interval(start=9.557039880213594, end=11.376097048183983, label='a'),
#   Interval(start=11.376097048183983, end=11.700943223867077, label='small'),
#   Interval(start=11.700943223867077, end=11.867316341921498, label='cut'),
#   Interval(start=11.867316341921498, end=12.135611730495745, label='back'),
#   Interval(start=12.135611730495745, end=12.532808814139184, label='this'),
#   Interval(start=12.532808814139184, end=13.152137772263675, label='errm'),
#   Interval(start=13.152137772263675, end=13.923158597015144, label='black-and-white'),
#   Interval(start=15.012827577425632, end=16.680315397129277, label='err'),
#   Interval(start=16.680315397129277, end=18.91452162563262, label='I'),
#   Interval(start=18.91452162563262, end=19.12436159434991, label='did'),
#   Interval(start=19.12436159434991, end=19.294334463177684, label='get'),
#   Interval(start=19.294334463177684, end=19.399254447536325, label='that'),
#   Interval(start=19.399254447536325, end=19.78446067582449, label='many'),
#   Interval(start=19.78446067582449, end=21.325291920217754, label='books'),
#   Interval(start=22.189536657022934, end=22.433405058573275, label='the'),
#   Interval(start=22.433405058573275, end=22.659732453404065, label='did'),
#   Interval(start=22.659732453404065, end=22.901048417428946, label='but'),
#   Interval(start=22.901048417428946, end=23.114789187328082, label='erm'),
#   Interval(start=27.4070942759655, end=27.66909951769422, label='but'),
#   Interval(start=27.66909951769422, end=27.789008071246958, label='I'),
#   Interval(start=27.789008071246958, end=27.91790976631615, label='did'),
#   Interval(start=27.91790976631615, end=28.034820606030067, label='get'),
#   Interval(start=28.034820606030067, end=28.10676573816171, label='a'),
#   Interval(start=28.10676573816171, end=28.496468537208102, label='few'),
#   Interval(start=28.496468537208102, end=29.05929241218411, label='computers'),
#   Interval(start=29.05929241218411, end=29.502207797489827, label='games'),
#   Interval(start=29.502207797489827, end=29.6613876813557, label='and'),
#   Interval(start=29.6613876813557, end=29.71534653045443, label='the'),
#   Interval(start=29.71534653045443, end=30.509740697741307, label='computers'),
#   Interval(start=30.810264675703152, end=32.189068815654764, label='console'),
#   Interval(start=32.189068815654764, end=32.5272147737473, label='which'),
#   Interval(start=32.5272147737473, end=32.919915286632516, label='for'),
#   Interval(start=32.919915286632516, end=33.141746110705085, label='the'),
#   Interval(start=33.141746110705085, end=33.50641988579302, label='play'),
#   Interval(start=33.50641988579302, end=34.84430334524907, label='playstation'),
#   Interval(start=34.84430334524907, end=35.52778843174026, label='2'),
#   Interval(start=35.52778843174026, end=36.94780797135532, label='errm'),
#   Interval(start=38.81344819071518, end=38.930359030429095, label='and'),
#   Interval(start=38.930359030429095, end=39.1267092868717, label="that's"),
#   Interval(start=39.1267092868717, end=39.34179842042722, label='quite'),
#   Interval(start=39.34179842042722, end=39.731651712736635, label='good'),
#   Interval(start=40.885175771105345, end=41.13623747072669, label='to'),
#   Interval(start=41.26214145195706, end=41.48757209068542, label='apply'),
#   Interval(start=41.48757209068542, end=41.80383090068076, label='on'),
#   Interval(start=41.80383090068076, end=42.47607133077365, label='errm'),
#   Interval(start=46.15128115964622, end=46.558525029294614, label='I'),
#   Interval(start=52.51830645235405, end=52.86454240073758, label='think'),
#   Interval(start=53.47982633177536, end=54.04534693406414, label='errm'),
#   Interval(start=56.6214430334558, end=57.000208621635416, label='undergo'),
#   Interval(start=57.000208621635416, end=57.175574881206295, label='of'),
#   Interval(start=57.175574881206295, end=57.413893131392356, label='a'),
#   Interval(start=57.413893131392356, end=57.87838821926374, label='small'),
#   Interval(start=57.87838821926374, end=58.15568308059504, label='piee'),
#   Interval(start=58.15568308059504, end=58.64535774957035, label='pieces'),
#   Interval(start=58.64535774957035, end=59.48607225545404, label='for'),
#   Interval(start=61.17274416470152, end=61.3645978503859, label='my'),
#   Interval(start=61.3645978503859, end=61.81875149696689, label='cats'),
#   Interval(start=61.81875149696689, end=62.40900640404622, label='bite'),
#   Interval(start=62.40900640404622, end=62.837679482997245, label='them'),
#   Interval(start=63.261410778759135, end=63.577669588754475, label='this'),
#   Interval(start=64.05520917646962, end=64.42542683556368, label='this'),
#   Interval(start=64.42542683556368, end=64.70316690932592, label='thing'),
#   Interval(start=64.70316690932592, end=64.8980183088491, label='that'),
#   Interval(start=64.8980183088491, end=65.76495970908461, label='looks'),
#   Interval(start=65.76495970908461, end=65.9278899008693, label='looks'),
#   Interval(start=65.9278899008693, end=66.1047550173596, label='like'),
#   Interval(start=66.1047550173596, end=66.19018986176592, label='a'),
#   Interval(start=66.19018986176592, end=66.48696353180894, label='slice'),
#   Interval(start=66.48696353180894, end=66.61886294071694, label='the'),
#   Interval(start=66.61886294071694, end=67.2432905065342, label='cheese'),
#   Interval(start=67.2432905065342, end=67.44563619065444, label='with'),
#   Interval(start=67.44563619065444, end=68.38962133071435, label='ho'),
#   Interval(start=68.38962133071435, end=68.91662319677, label='holes'),
#   Interval(start=68.91662319677, end=69.28968807643987, label='in'),
#   Interval(start=69.94094457354348, end=70.12830168846962, label='and'),
#   Interval(start=70.12830168846962, end=70.27609275391475, label='you'),
#   Interval(start=70.27609275391475, end=70.48293500879322, label='put'),
#   Interval(start=70.48293500879322, end=71.25230015212166, label='ball'),
#   Interval(start=72.11804368196381, end=72.32249032382045, label='in'),
#   Interval(start=72.32249032382045, end=72.57729600012001, label='it'),
#   Interval(start=72.57729600012001, end=72.81261653646725, label='and'),
#   Interval(start=72.81261653646725, end=73.26377246920941, label='then'),
#   Interval(start=73.26377246920941, end=73.72212796738074, label='pause'),
#   Interval(start=73.72212796738074, end=73.92297479458158, label='and'),
#   Interval(start=73.92297479458158, end=74.40260900879251, label='then'),
#   Interval(start=74.40260900879251, end=74.4922457047892, label='play'),
#   Interval(start=74.4922457047892, end=74.56568969384026, label='with'),
#   Interval(start=74.56568969384026, end=74.77702851947694, label='that'),
#   Interval(start=74.77702851947694, end=75.37597551766424, label='pause'),
#   Interval(start=75.37597551766424, end=75.47939664510348, label='and'),
#   Interval(start=75.47939664510348, end=75.65026633391614, label='then'),
#   Interval(start=75.65026633391614, end=76.07954151368415, label='play'),
#   Interval(start=76.07954151368415, end=76.22792834870566, label='with'),
#   Interval(start=76.22792834870566, end=76.4977225941993, label='that'),
#   Interval(start=77.24670577759055, end=77.39809032645087, label='and'),
#   Interval(start=77.39809032645087, end=77.48052745701838, label='I'),
#   Interval(start=77.48052745701838, end=77.66938342886394, label='quite'),
#   Interval(start=77.66938342886394, end=77.85524168687067, label='like'),
#   Interval(start=77.85524168687067, end=78.09655765089555, label='that'),
#   Interval(start=78.80057519058697, end=79.07186829300002, label='they'),
#   Interval(start=79.97673265989228, end=80.18282865193135, label='even'),
#   Interval(start=80.18282865193135, end=80.386673192971, label='play'),
#   Interval(start=80.386673192971, end=80.67985337959882, label='never'),
#   Interval(start=80.67985337959882, end=80.92416705746253, label='quite'),
#   Interval(start=80.92416705746253, end=81.37532299020468, label='long'),
#   Interval(start=82.23956766312743, end=82.92410006286654, label='errm'),
#   Interval(start=86.83703237234879, end=87.76437952914972, label='we'),
#   Interval(start=87.76437952914972, end=88.11121757835024, label='went'),
#   Interval(start=88.11121757835024, end=88.34953582853629, label='out'),
#   Interval(start=88.34953582853629, end=88.5225064112029, label='for'),
#   Interval(start=88.5225064112029, end=88.67389096006322, label='a'),
#   Interval(start=88.67389096006322, end=89.02312462228556, label='meal'),
#   Interval(start=89.02312462228556, end=89.2929188677792, label='on'),
#   Interval(start=89.2929188677792, end=89.79428967294189, label='christmas'),
#   Interval(start=89.79428967294189, end=90.19898104118236, label='day'),
#   Interval(start=90.19898104118236, end=90.59723176931432, label='to'),
#   Interval(start=90.59723176931432, end=90.66468033068773, label='the'),
#   Interval(start=90.66468033068773, end=91.87261478182667, label='space'),
#   Interval(start=91.87261478182667, end=92.21735187329078, label='was'),
#   Interval(start=93.11756917616181, end=93.35438856942845, label='quite'),
#   Interval(start=93.35438856942845, end=93.7195138881879, label='good'),
#   Interval(start=95.26738787350669, end=95.76606195135662, label='and'),
#   Interval(start=95.95102345326092, end=96.6315044946727, label='infected'),
#   Interval(start=96.6315044946727, end=97.03364969274588, label='nice'),
#   Interval(start=97.26327585182398, end=97.7168337288286, label='errm'),
#   Interval(start=104.75069979352807, end=105.40420141039047, label='errm'),
#   Interval(start=107.15382531025313, end=107.76744751147258, label='that'),
#   Interval(start=107.76744751147258, end=108.2111091596177, label='we'),
#   Interval(start=109.1374121972932, end=109.37872816131808, label='came'),
#   Interval(start=109.37872816131808, end=109.58257270235774, label='back'),
#   Interval(start=109.58257270235774, end=109.8853418000784, label='from'),
#   Interval(start=109.8853418000784, end=110.42898164939301, label='that'),
#   Interval(start=110.79170502389003, end=111.1911535585329, label='and'),
#   Interval(start=111.1911535585329, end=111.36951753194259, label='we'),
#   Interval(start=111.36951753194259, end=111.62282435132273, label='had'),
#   Interval(start=112.57849929632943, end=112.90585220557762, label='and'),
#   Interval(start=114.14316169428777, end=114.98222684998902, label='tea'),
#   Interval(start=114.98222684998902, end=115.53201262024432, label='and'),
#   Interval(start=115.53201262024432, end=115.97417541147003, label='on'),
#   Interval(start=116.70202416860897, end=117.15018238751232, label='boxing'),
#   Interval(start=117.15018238751232, end=118.05849601191491, label='debris'),
#   Interval(start=118.05849601191491, end=118.47068166475243, label='my'),
#   Interval(start=118.47068166475243, end=118.70495488785178, label='mum'),
#   Interval(start=118.70495488785178, end=118.99513736064078, label='cook'),
#   Interval(start=118.99513736064078, end=119.57219727461332, label='to'),
#   Interval(start=119.57219727461332, end=120.24818174526686, label='Melbourne'),
#   Interval(start=120.75615001504175, end=120.99596712214722, label='they'),
#   Interval(start=120.99596712214722, end=121.28074993683497, label="shouldn't"),
#   Interval(start=121.28074993683497, end=121.49479175714261, label='have'),
#   Interval(start=121.49479175714261, end=121.80805285329913, label='to'),
#   Interval(start=121.80805285329913, end=123.21713524592982, label='mail'),
#   Interval(start=123.21713524592982, end=123.4254763577277, label='twice'),
#   Interval(start=124.31984866230165, end=124.81297258878728, label='errm')],
#  'AllAudioWav/F_0101_15y2m_1.wav',
#  [Interval(start=0.0, end=1.3163004686333666, label='errm'),
#   Interval(start=2.7161218049230804, end=3.021666563605607, label='okay'),
#   Interval(start=3.021666563605607, end=3.426691011161514, label="I'm"),
#   Interval(start=3.426691011161514, end=3.561699160346816, label='in'),
#   Interval(start=3.561699160346816, end=3.931195147590802, label='year'),
#   Interval(start=3.931195147590802, end=4.549390357018239, label='10'),
#   Interval(start=4.549390357018239, end=4.790983887139307, label='and'),
#   Interval(start=4.790983887139307, end=4.989943264886068, label='this'),
#   Interval(start=4.989943264886068, end=5.494447401315355, label='year'),
#   Interval(start=5.494447401315355, end=5.861876351052082, label="I'm"),
#   Interval(start=5.861876351052082, end=5.989778808175, label='doing'),
#   Interval(start=5.989778808175, end=6.10346988117315, label='my'),
#   Interval(start=6.10346988117315, end=6.373486179543754, label='first'),
#   Interval(start=6.373486179543754, end=6.558234173165747, label='year'),
#   Interval(start=6.558234173165747, end=6.913518776284963, label='of'),
#   Interval(start=6.913518776284963, end=7.297226147653718, label='errm'),
#   Interval(start=7.297226147653718, end=8.199649039576528, label='GCSEs'),
#   Interval(start=9.161436823945365, end=10.227290633303015, label='errm'),
#   Interval(start=10.227290633303015, end=10.875067419183173, label="I'm"),
#   Interval(start=10.875067419183173, end=11.770384619043599, label='studying'),
#   Interval(start=11.770384619043599, end=12.637279050654486, label='art'),
#   Interval(start=12.637279050654486, end=13.6747100917626, label='history'),
#   Interval(start=13.6747100917626, end=14.521143474062304, label='erm'),
#   Interval(start=14.521143474062304, end=14.741419927996219, label='triple'),
#   Interval(start=14.741419927996219, end=15.586997283419954, label='science'),
#   Interval(start=16.382834794407, end=16.925386747095157, label='and'),
#   Interval(start=16.925386747095157, end=18.637858534129784, label='stammered_spanish'),
#   Interval(start=19.586694612347326, end=19.97040198371608, label='and'),
#   Interval(start=19.97040198371608, end=20.28305243446099, label='errm'),
#   Interval(start=20.28305243446099, end=20.617019961393055, label='graphical'),
#   Interval(start=20.617019961393055, end=21.34890624381864, label='design'),
#   Interval(start=22.144743754805685, end=22.806405266410195, label='errm'),
#   Interval(start=26.35214560553997, end=26.634104510987505, label='and'),
#   Interval(start=26.634104510987505, end=26.783324044297576, label='my'),
#   Interval(start=26.783324044297576, end=27.046234650605793, label='favorite'),
#   Interval(start=27.046234650605793, end=27.607584323534155, label='subject'),
#   Interval(start=27.607584323534155, end=28.20446245677444, label='of'),
#   Interval(start=28.20446245677444, end=28.85108043445141, label='all'),
#   Interval(start=28.85108043445141, end=29.38400733913024, label='all'),
#   Interval(start=30.726983138920875, end=31.735991411779448, label='of all of'),
#   Interval(start=31.735991411779448, end=32.31155246883257, label='them'),
#   Interval(start=32.31155246883257, end=32.54533393180533, label='is'),
#   Interval(start=32.54533393180533, end=32.82956161430071, label='erm'),
#   Interval(start=32.82956161430071, end=33.39801697929145, label='art'),
#   Interval(start=33.39801697929145, end=34.67704155052063, label='errm'),
#   Interval(start=37.61955316411465, end=38.52197605603746, label='and'),
#   Interval(start=42.48176038541685, end=43.12127267103144, label='okay'),
#   Interval(start=43.12127267103144, end=43.263386512279126, label='are'),
#   Interval(start=43.263386512279126, end=43.39839466146443, label='my'),
#   Interval(start=43.39839466146443, end=43.58314265508642, label='friends'),
#   Interval(start=43.58314265508642, end=44.052118331203786, label='are'),
#   Interval(start=44.052118331203786, end=44.89769568662752, label='erm'),
#   Interval(start=44.89769568662752, end=45.75738355640573, label='stammered_Lisa'),
#   Interval(start=45.75738355640573, end=47.128782124445905, label='errm'),
#   Interval(start=47.128782124445905, end=47.898514368912224, label='Lisa'),
#   Interval(start=47.898514368912224, end=48.495392502152505, label='Charlotte'),
#   Interval(start=49.788628457506455, end=50.80474242242741, label='Eleanor'),
#   Interval(start=50.80474242242741, end=52.094550792530335, label='and'),
#   Interval(start=52.094550792530335, end=52.84064845908069, label='Sarah'),
#   Interval(start=59.14072489027025, end=59.481798109264695, label='and'),
#   Interval(start=59.481798109264695, end=60.06446485838021, label='this'),
#   Interval(start=60.06446485838021, end=61.32217235342224, label='tuesday'),
#   Interval(start=61.32217235342224, end=61.696908849439495, label="I'm"),
#   Interval(start=61.696908849439495, end=62.39326667155316, label='meeting'),
#   Interval(start=62.39326667155316, end=62.54248620486323, label='up'),
#   Interval(start=62.54248620486323, end=63.13936433810351, label='with'),
#   Interval(start=63.13936433810351, end=63.67939693484472, label='with'),
#   Interval(start=63.67939693484472, end=64.20521814746117, label='most'),
#   Interval(start=64.20521814746117, end=64.63866536326661, label='them'),
#   Interval(start=65.29042297994656, end=65.57465066244194, label='to'),
#   Interval(start=65.57465066244194, end=65.93704095762354, label='go'),
#   Interval(start=65.93704095762354, end=66.75419554479774, label='shopping'),
#   Interval(start=67.60491632358362, end=67.7541358568937, label='and'),
#   Interval(start=67.7541358568937, end=67.9744123108276, label='then'),
#   Interval(start=67.9744123108276, end=68.08810338382575, label='to'),
#   Interval(start=68.08810338382575, end=68.24442860919821, label='have'),
#   Interval(start=68.24442860919821, end=68.32259122188444, label='a'),
#   Interval(start=68.32259122188444, end=68.94078643131188, label='sleepover'),
#   Interval(start=73.36984916079706, end=73.62565407504289, label='and'),
#   Interval(start=73.62565407504289, end=73.76776791629058, label='we'),
#   Interval(start=73.76776791629058, end=73.95251590991256, label='should'),
#   Interval(start=73.95251590991256, end=74.27937774478225, label='be'),
#   Interval(start=74.27937774478225, end=75.48734539538759, label='fine'),
#   Interval(start=83.47787016233868, end=83.63419538771113, label='I'),
#   Interval(start=84.08185398764135, end=84.33765890188718, label='stammered_think'),
#   Interval(start=84.33765890188718, end=84.47266705107248, label='that'),
#   Interval(start=85.23297610174761, end=85.38930132712007, label='should'),
#   Interval(start=85.47456963186868, end=85.63800054930351, label='think'),
#   Interval(start=85.63800054930351, end=85.7801143905512, label='for'),
#   Interval(start=85.7801143905512, end=86.07855345717134, label='a'),
#   Interval(start=86.07855345717134, end=86.98808204115653, label='halftime'),
#   Interval(start=89.50384847991, end=90.11493799727505, label='this'),
#   Interval(start=90.11493799727505, end=91.20921457488224, label='friday'),
#   Interval(start=92.03347485411882, end=92.23953992392796, label='my'),
#   Interval(start=92.23953992392796, end=92.51666191436095, label='sister'),
#   Interval(start=92.51666191436095, end=92.90747497779209, label='leaving'),
#   Interval(start=92.90747497779209, end=93.05669451110217, label='go'),
#   Interval(start=93.05669451110217, end=93.29828804122323, label='to'),
#   Interval(start=93.29828804122323, end=94.15807678077174, label='Australia'),
#   Interval(start=94.15807678077174, end=94.48861672245278, label='for'),
#   Interval(start=94.48861672245278, end=94.76573871288576, label='a'),
#   Interval(start=94.76573871288576, end=95.57578760799757, label='year'),
#   Interval(start=97.82194139947794, end=98.063534929599, label='and'),
#   Interval(start=98.063534929599, end=99.49888472620063, label='also'),
#   Interval(start=100.90959078847314, end=101.44251769315197, label="she's"),
#   Interval(start=101.44251769315197, end=102.01807875020509, label='planning'),
#   Interval(start=102.01807875020509, end=102.1104527470161, label='to'),
#   Interval(start=102.1104527470161, end=102.3378348930124, label='go'),
#   Interval(start=102.3378348930124, end=103.20472932462329, label='to'),
#   Interval(start=103.77404071649002, end=104.80436606553575, label='Thailand'),
#   Interval(start=107.72430098230791, end=108.01563435686566, label='to'),
#   Interval(start=108.01563435686566, end=108.7759434075408, label='Thailand'),
#   Interval(start=108.7759434075408, end=110.55236642313687, label='Newzealand'),
#   Interval(start=110.55236642313687, end=111.4000795187853, label='Australia'),
#   Interval(start=111.4000795187853, end=111.8122096584036, label='and'),
#   Interval(start=111.8122096584036, end=113.43941314068961, label='stmmered_America')],
#  'AllAudioWav/F_0111_09y6m_1.wav',
#  [Interval(start=0.0, end=13.074182891878145, label='stammered_today'),
#   Interval(start=13.074182891878145, end=23.0217388748765, label='stammered_we'),
#   Interval(start=23.0217388748765, end=33.47602985471239, label='stammered_games'),
#   Interval(start=33.47602985471239, end=35.01603266540411, label='and'),
#   Interval(start=35.01603266540411, end=35.91845555732692, label='and'),
#   Interval(start=35.91845555732692, end=47.0925558356684, label='stammered_we'),
#   Interval(start=47.0925558356684, end=54.4886588660623, label='stammered_we'),
#   Interval(start=54.4886588660623, end=55.70389361536755, label='stammered_won'),
#   Interval(start=55.70389361536755, end=56.066283910549146, label='we'),
#   Interval(start=56.066283910549146, end=59.30962385149866, label='stammered_played'),
#   Interval(start=59.30962385149866, end=64.33740600020064, label='stammered_with'),
#   Interval(start=64.33740600020064, end=69.6128683666691, label='stammered_where'),
#   Interval(start=72.37048746107392, end=73.35107296568296, label='UNKOWN'),
#   Interval(start=74.70521231813225, end=75.62895228624222, label='UNKNOWN_t'),
#   Interval(start=75.62895228624222, end=76.93609215687154, label='UNKNOWN_p'),
#   Interval(start=76.93609215687154, end=79.61290455672089, label='stammered_pool'),
#   Interval(start=79.61290455672089, end=81.49195623348035, label='stammered_to'),
#   Interval(start=81.49195623348035, end=84.15699475475999, label='stammered_people'),
#   Interval(start=84.15699475475999, end=84.80361273243696, label='people'),
#   Interval(start=84.80361273243696, end=87.02576191228493, label='UNKNOWN_p'),
#   Interval(start=87.02576191228493, end=90.33416854641635, label='UNKNOWN_b'),
#   Interval(start=90.33416854641635, end=91.86899803189137, label='UNKNOWN_f'),
#   Interval(start=91.86899803189137, end=95.34357601490699, label='UNKNOWN_y'),
#   Interval(start=95.34357601490699, end=98.96335161673758, label='stammered_throw'),
#   Interval(start=98.96335161673758, end=99.12735255048324, label='it'),
#   Interval(start=99.12735255048324, end=102.7299384261121, label='stammered_you'),
#   Interval(start=102.7299384261121, end=104.25298942122966, label='stammered_cold'),
#   Interval(start=104.25298942122966, end=104.91381878303139, label='out'),
#   Interval(start=107.56210752209601, end=108.03108319821338, label='out'),
#   Interval(start=108.03108319821338, end=108.40534851278852, label='the'),
#   Interval(start=108.40534851278852, end=110.81651448666803, label='stammered_past'),
#   Interval(start=110.81651448666803, end=115.86621967396911, label='UNKOWN_n'),
#   Interval(start=115.86621967396911, end=116.97094833750002, label='the'),
#   Interval(start=116.97094833750002, end=121.47893544712868, label='stammered_to'),
#   Interval(start=121.47893544712868, end=122.0931333788948, label='your'),
#   Interval(start=122.0931333788948, end=124.87856466734947, label='UNKNOWN_c_k'),
#   Interval(start=124.87856466734947, end=125.73835340689797, label='UNKNOWN_b'),
#   Interval(start=125.73835340689797, end=126.82887068630407, label='stammered_with'),
#   Interval(start=126.82887068630407, end=129.47218813351103, label='stammered_to'),
#   Interval(start=130.18275733974946, end=131.79949976082497, label='stammered_throw'),
#   Interval(start=131.79949976082497, end=132.21873559250565, label='it'),
#   Interval(start=132.21873559250565, end=137.64224158239404, label='UNKNOWN_t')],
#  'AllAudioWav/F_0558_09y3m_1.wav',
#  [Interval(start=4.194105753899022, end=5.743146623498807, label='because'),
#   Interval(start=5.743146623498807, end=5.931999564013645, label='I'),
#   Interval(start=5.931999564013645, end=6.3938695480686265, label='like'),
#   Interval(start=6.3938695480686265, end=6.543089081378698, label='to'),
#   Interval(start=6.543089081378698, end=6.841528147998839, label='watch'),
#   Interval(start=6.841528147998839, end=7.552097354237273, label='because'),
#   Interval(start=9.605642360266346, end=9.87565865863695, label='I'),
#   Interval(start=9.87565865863695, end=10.145674957007554, label='like'),
#   Interval(start=10.145674957007554, end=10.707024629935917, label='seeing'),
#   Interval(start=10.707024629935917, end=11.005463696556058, label='lot'),
#   Interval(start=11.005463696556058, end=11.140471845741361, label='of'),
#   Interval(start=11.140471845741361, end=11.311008455238586, label='the'),
#   Interval(start=11.311008455238586, end=12.362677015091542, label='people'),
#   Interval(start=12.362677015091542, end=12.865527634651478, label='and'),
#   Interval(start=14.755641723245711, end=14.947495408930088, label='I'),
#   Interval(start=14.947495408930088, end=15.253040167612614, label='like'),
#   Interval(start=15.253040167612614, end=15.977820757975815, label='watching'),
#   Interval(start=15.977820757975815, end=16.03466629447489, label='my'),
#   Interval(start=16.03466629447489, end=16.752341192775706, label='favorite'),
#   Interval(start=16.752341192775706, end=17.782666541821435, label='wrestler'),
#   Interval(start=17.782666541821435, end=18.160338612725393, label='stuff'),
#   Interval(start=31.50698556791893, end=31.812530326601458, label='oh'),
#   Interval(start=31.812530326601458, end=32.06833524084729, label='yeah'),
#   Interval(start=32.06833524084729, end=32.23176615828213, label='i'),
#   Interval(start=32.23176615828213, end=32.608367837588496, label='like'),
#   Interval(start=32.608367837588496, end=33.212351662891166, label='watching'),
#   Interval(start=33.212351662891166, end=34.21425424368735, label='tele'),
#   Interval(start=35.358270665731226, end=35.52170158316606, label='i'),
#   Interval(start=35.52170158316606, end=35.734872345037594, label='like'),
#   Interval(start=35.734872345037594, end=36.25648169132478, label='listening'),
#   Interval(start=36.45544106907154, end=37.0594248943742, label='news')],
#  'AllAudioWav/F_0558_10y0m_1.wav',
#  [Interval(start=0.6987146227344894, end=0.9668226541938076, label='I'),
#   Interval(start=0.9668226541938076, end=1.1641096962110433, label='love'),
#   Interval(start=1.1641096962110433, end=1.565896889143094, label='watching'),
#   Interval(start=1.565896889143094, end=2.420807404551111, label='Neighbours'),
#   Interval(start=2.420807404551111, end=3.395407541177057, label='EastEnders'),
#   Interval(start=3.395407541177057, end=4.2820128442003975, label='Dawson creek'),
#   Interval(start=4.796276549452796, end=5.190850633487266, label='chub'),
#   Interval(start=5.3501978597319555, end=5.512074407028148, label='which'),
# ...
#   Interval(start=87.06120320242832, end=87.33987992511007, label='and'),
#   Interval(start=87.66318891394855, end=87.9616279805687, label='all'),
#   Interval(start=87.9616279805687, end=88.41639227256128, label='that'),
#   Interval(start=92.19785832437728, end=92.82315922586709, label="it's"),
#   Interval(start=92.82315922586709, end=93.46622435751287, label='been'),
#   Interval(start=93.46622435751287, end=94.16613502565772, label='round'),
#   Interval(start=94.16613502565772, end=94.54628955099528, label='for'),
#   Interval(start=94.54628955099528, end=96.1981728957109, label='stammered_lots'),
#   Interval(start=96.1981728957109, end=97.6971571317328, label='stammered_of'),
#   Interval(start=98.08441734913274, end=99.71162083141873, label='stammered_years'),
#   Interval(start=100.35798541887073, end=100.70616432992755, label='and'),
#   Interval(start=104.74705147245683, end=104.96732792639074, label='it'),
#   Interval(start=106.92139324354642, end=107.23759654032251, label='it'),
#   Interval(start=107.87074883478097, end=108.42486608629446, label='and'),
#   Interval(start=109.82630548526916, end=110.11053316776453, label='and'),
#   Interval(start=111.16721977236111, end=111.72501659925828, label='and'),
#   Interval(start=111.72501659925828, end=112.45335003565268, label='stammered_got'),
#   Interval(start=112.45335003565268, end=112.82446401710163, label='got'),
#   Interval(start=112.82446401710163, end=113.10158600753462, label='got'),
#   Interval(start=113.10158600753462, end=113.31120392337496, label='got'),
#   Interval(start=113.31120392337496, end=113.76436664550121, label='made'),
#   Interval(start=113.76436664550121, end=113.87805771849936, label='to'),
#   Interval(start=114.7200822278919, end=115.25105785640586, label='tell'),
#   Interval(start=117.18469159645177, end=117.38963084577722, label='sort'),
#   Interval(start=117.38963084577722, end=117.5814845314616, label='of'),
#   Interval(start=117.5814845314616, end=121.82575632802754, label="stammered_what's"),
#   Interval(start=135.46337803512188, end=136.08512609058047, label='stammered_going'),
#   Interval(start=136.08512609058047, end=136.66779283969595, label='stammered_on')],
#  'AllAudioWav/M_0078_16y5m_1.wav',
#  [Interval(start=4.407276515770552, end=4.620447277642081, label="i'm"),
#   Interval(start=4.620447277642081, end=4.755455426827384, label='at'),
#   Interval(start=4.755455426827384, end=5.668445081080272, label='stammered_Saint'),
#   Interval(start=6.309662131535502, end=6.60099550609326, label='Saint'),
#   Interval(start=6.60099550609326, end=7.119711026647316, label="John's"),
#   Interval(start=9.133899399042777, end=9.609980767222527, label='doing'),
#   Interval(start=9.609980767222527, end=10.000793830653665, label='my'),
#   Interval(start=10.000793830653665, end=10.889005338451707, label='A'),
#   Interval(start=13.926958802551756, end=14.48830847548012, label='S'),
#   Interval(start=17.61590447126478, end=18.56059448986953, label='levels'),
#   Interval(start=18.944301861238284, end=19.143261238985044, label="I'm"),
#   Interval(start=19.143261238985044, end=19.391960461168495, label='doing'),
#   Interval(start=19.391960461168495, end=20.10252966740693, label='four'),
#   Interval(start=20.10252966740693, end=20.386757349902304, label='which'),
#   Interval(start=20.386757349902304, end=20.607033803836217, label='is'),
#   Interval(start=20.607033803836217, end=21.346025778324186, label='stammered_changed'),
#   Interval(start=21.346025778324186, end=21.95711529568924, label='this'),
#   Interval(start=22.49532297160323, end=23.099306796905896, label='normally'),
#   Interval(start=23.099306796905896, end=23.660656469834258, label='three'),
#   Interval(start=25.210059222628292, end=25.416124292437438, label="I'm"),
#   Interval(start=25.416124292437438, end=25.607977978121816, label='doing'),
#   Interval(start=25.607977978121816, end=26.304335800235478, label='maths'),
#   Interval(start=26.304335800235478, end=26.943848085850068, label='IT'),
#   Interval(start=26.943848085850068, end=27.412823761967434, label='Art'),
#   Interval(start=27.412823761967434, end=31.823088254521274, label='stammered_physics'),
#   Interval(start=32.563716378449726, end=32.86926113713225, label='all'),
#   Interval(start=32.86926113713225, end=32.947423749818476, label='of'),
#   Interval(start=32.947423749818476, end=33.125066051378084, label='which'),
#   Interval(start=33.125066051378084, end=33.252968508501006, label='i'),
#   Interval(start=33.252968508501006, end=33.530090498933994, label="can't"),
#   Interval(start=33.530090498933994, end=33.84984664174129, label='stand'),
#   Interval(start=33.84984664174129, end=33.96353771473944, label='is'),
#   Interval(start=33.96353771473944, end=34.141180016299046, label='that'),
#   Interval(start=34.141180016299046, end=34.716741073352175, label='Art'),
#   Interval(start=34.95122891141086, end=35.342041974842, label='plus'),
#   Interval(start=35.711537962085984, end=36.08103394932997, label='loads'),
#   Interval(start=36.08103394932997, end=36.507375473073026, label='of'),
#   Interval(start=36.838789170291264, end=37.151439621036175, label='work'),
#   Interval(start=37.151439621036175, end=37.3219762305334, label='but'),
#   Interval(start=37.3219762305334, end=37.52093560828016, label='i'),
#   Interval(start=37.52093560828016, end=38.06096820502137, label='got'),
#   Interval(start=40.08207879531384, end=40.35209509368445, label='to'),
#   Interval(start=40.35209509368445, end=40.70027400474128, label='done'),
#   Interval(start=40.70027400474128, end=40.81396507773943, label='by'),
#   Interval(start=40.81396507773943, end=40.91344476661281, label='the'),
#   Interval(start=40.91344476661281, end=41.325574906231104, label='start'),
#   Interval(start=41.325574906231104, end=42.05746118865669, label='term'),
#   Interval(start=42.58328240127313, end=42.70407916633366, label="she's"),
#   Interval(start=42.70407916633366, end=42.87461577583089, label='a'),
#   Interval(start=42.87461577583089, end=43.08068084564003, label='bit'),
#   Interval(start=43.08068084564003, end=43.87651835662708, label='worrying'),
#   Interval(start=46.342555385468685, end=46.797684113589405, label='physics'),
#   Interval(start=46.797684113589405, end=47.27376548176916, label='is'),
#   Interval(start=47.27376548176916, end=47.593521624576454, label="isn't"),
#   Interval(start=47.593521624576454, end=47.899066383258976, label='that'),
#   Interval(start=47.899066383258976, end=48.35383067525158, label='bad'),
#   Interval(start=48.35383067525158, end=48.5243672847488, label='but'),
#   Interval(start=48.5243672847488, end=48.609635589497415, label='we'),
#   Interval(start=48.609635589497415, end=48.77306650693225, label='got'),
#   Interval(start=48.77306650693225, end=48.95781450055424, label='this'),
#   Interval(start=48.95781450055424, end=49.55469263379453, label='teacher'),
#   Interval(start=49.55469263379453, end=50.024213744633144, label="who's"),
#   Interval(start=50.024213744633144, end=50.28001865887898, label='so'),
#   Interval(start=50.28001865887898, end=50.95505940480549, label='boring'),
#   Interval(start=50.95505940480549, end=51.2677098555504, label='he'),
#   Interval(start=51.2677098555504, end=51.4950920015467, label='could'),
#   Interval(start=53.07710750174457, end=53.5602945619867, label='just'),
#   Interval(start=56.07261036499732, end=56.52737465698991, label='sleeping'),
#   Interval(start=56.52737465698991, end=56.847130799797206, label='during'),
#   Interval(start=56.847130799797206, end=57.09583002198066, label='every'),
#   Interval(start=57.09583002198066, end=57.51506585366133, label='single'),
#   Interval(start=57.51506585366133, end=58.040887066277776, label='class'),
#   Interval(start=58.040887066277776, end=58.174799203522475, label='he'),
#   Interval(start=58.174799203522475, end=58.473238270142616, label='mostly'),
#   Interval(start=58.473238270142616, end=58.81431148913707, label="can't"),
#   Interval(start=58.81431148913707, end=59.11985624781959, label='stay'),
#   Interval(start=59.11985624781959, end=59.675196240626164, label='awake'),
#   Interval(start=62.97933782977514, end=63.56911027095304, label='so'),
#   Interval(start=63.810703801074105, end=64.10914286769425, label='due'),
#   Interval(start=64.10914286769425, end=64.2654680930667, label='to'),
#   Interval(start=64.2654680930667, end=64.35784208987769, label='the'),
#   Interval(start=64.35784208987769, end=65.21052513736382, label='approach'),
#   Interval(start=65.61864362949505, end=66.08051361355004, label='death'),
#   Interval(start=66.08051361355004, end=66.52817221348025, label='most'),
#   Interval(start=66.52817221348025, end=67.096627578471, label='time'),
#   Interval(start=68.00524370204258, end=68.20420307978934, label='with'),
#   Interval(start=68.20420307978934, end=68.46000799403517, label='you'),
#   Interval(start=69.16820692208677, end=69.45243460458214, label='slowing'),
#   Interval(start=69.45243460458214, end=69.71534521089036, label='down'),
#   Interval(start=69.71534521089036, end=69.80771920770135, label='and'),
#   Interval(start=69.80771920770135, end=70.2838005758811, label='everything'),
#   Interval(start=74.98375707369247, end=75.32483029268693, label='maths'),
#   Interval(start=75.32483029268693, end=75.76538320055475, label='is'),
#   Interval(start=76.2840987211088, end=76.83834270197478, label='getting'),
#   Interval(start=76.83834270197478, end=77.47785498758938, label='quiet'),
#   Interval(start=78.58233130183429, end=79.19342081919935, label='stammered_hard'),
#   Interval(start=79.19342081919935, end=79.39948588900849, label='which'),
#   Interval(start=79.39948588900849, end=79.78319326037725, label='mean'),
#   Interval(start=79.78319326037725, end=80.23795755236983, label='last'),
#   Interval(start=80.23795755236983, end=80.5719250793019, label='year'),
#   Interval(start=80.5719250793019, end=80.71403892054958, label='was'),
#   Interval(start=80.71403892054958, end=81.27775365180503, label='all'),
#   Interval(start=81.5619813343004, end=82.21570500403976, label='fine'),
#   Interval(start=82.21570500403976, end=82.35781884528744, label='but'),
#   Interval(start=82.35781884528744, end=82.63494083572043, label='now'),
#   Interval(start=82.63494083572043, end=82.81968882934243, label="we're"),
#   Interval(start=82.81968882934243, end=83.38814419433318, label='learning'),
#   Interval(start=83.38814419433318, end=83.81448571807624, label='loads'),
#   Interval(start=83.81448571807624, end=84.20529878150738, label='of'),
#   Interval(start=84.20529878150738, end=86.5075430097199, label='stammered_new'),
#   Interval(start=86.5075430097199, end=86.89835607315104, label='stuff'),
#   Interval(start=87.68016060904218, end=88.490209504154, label='everyday'),
#   Interval(start=89.31446978339058, end=89.62001454207311, label='and'),
#   Interval(start=89.62001454207311, end=89.81186822775749, label='the'),
#   Interval(start=89.81186822775749, end=90.36611220862346, label='work'),
#   Interval(start=90.36611220862346, end=90.77113665617938, label='load'),
#   Interval(start=90.77113665617938, end=91.1193155672362, label='is'),
#   Interval(start=91.1193155672362, end=91.85830754172417, label='huge'),
#   Interval(start=92.48888921444915, end=92.63810874775922, label='the'),
#   Interval(start=92.63810874775922, end=93.0076047350032, label='moment'),
#   Interval(start=93.0076047350032, end=93.45526333493342, label='such'),
#   Interval(start=93.45526333493342, end=93.84607639836456, label='quite'),
#   Interval(start=93.84607639836456, end=102.18213883712416, label='stammered_worrying'),
#   Interval(start=102.18213883712416, end=102.59426897674246, label='sings'),
#   Interval(start=102.80743973861398, end=103.35457802741757, label='exams'),
#   Interval(start=106.54612455550897, end=107.31353929824648, label='arts'),
#   Interval(start=107.31353929824648, end=107.6688239013657, label='quite'),
#   Interval(start=107.6688239013657, end=107.91041743148676, label='fun'),
#   Interval(start=108.60057680209192, end=108.71426787509007, label='not'),
#   Interval(start=108.71426787509007, end=108.9700727893359, label='really'),
#   Interval(start=108.9700727893359, end=109.27471030746456, label='that'),
#   Interval(start=110.20646320819078, end=111.07335763980167, label='intense'),
#   Interval(start=111.07335763980167, end=111.86208945872633, label='so'),
#   Interval(start=113.41987216982895, end=113.59751447138856, label="it's"),
#   Interval(start=113.59751447138856, end=113.93858769038302, label='quite'),
#   Interval(start=113.93858769038302, end=114.308083677627, label='good'),
#   Interval(start=115.80428551571666, end=116.06719612202487, label='left'),
#   Interval(start=116.06719612202487, end=116.33721242039547, label='sort of'),
#   Interval(start=116.33721242039547, end=116.57170025845417, label='Z'),
#   Interval(start=116.57170025845417, end=116.79197671238809, label='quite'),
#   Interval(start=116.79197671238809, end=116.89856209332385, label='a'),
#   Interval(start=116.89856209332385, end=117.18278977581923, label='bit'),
#   Interval(start=117.18278977581923, end=117.37464346150361, label='on'),
#   Interval(start=117.37464346150361, end=117.6517654519366, label='that'),
#   Interval(start=117.8720419058705, end=118.09067699050418, label='so'),
#   Interval(start=118.09067699050418, end=118.66077372479518, label='hopefully'),
#   Interval(start=122.57527599978418, end=123.42795904727029, label='IT'),
#   Interval(start=123.76903226626474, end=124.41565024394173, label='that'),
#   Interval(start=125.77174141591655, end=126.0630747904743, label='up'),
#   Interval(start=126.0630747904743, end=126.26913986028346, label='and'),
#   Interval(start=126.26913986028346, end=126.64574153958982, label='down'),
#   Interval(start=126.64574153958982, end=126.78074968877513, label='it'),
#   Interval(start=126.78074968877513, end=127.03655460302096, label='can'),
#   Interval(start=127.03655460302096, end=127.37052212995303, label='be'),
#   Interval(start=127.37052212995303, end=128.0668799520667, label='okay'),
#   Interval(start=128.0668799520667, end=128.3368962504373, label='it'),
#   Interval(start=128.3368962504373, end=128.54296132024643, label='can'),
#   Interval(start=128.54296132024643, end=128.68507516149413, label='be'),
#   Interval(start=128.68507516149413, end=128.99772561223904, label='really'),
#   Interval(start=128.99772561223904, end=129.56618097722978, label='dull'),
#   Interval(start=129.56618097722978, end=130.00709576829186, label='talking'),
#   Interval(start=130.00709576829186, end=130.39080313966062, label='about'),
#   Interval(start=131.66272201882742, end=132.56514491075023, label='sounds'),
#   Interval(start=132.56514491075023, end=133.06254335511713, label='from'),
#   Interval(start=135.20718287185124, end=135.91064638602728, label='inputs'),
#   Interval(start=135.91064638602728, end=136.2659309891465, label='and'),
#   Interval(start=136.2659309891465, end=136.94097173507302, label='outputs'),
#   Interval(start=136.94097173507302, end=137.16835388106932, label='of'),
#   Interval(start=138.3169221654617, end=139.02038567963777, label='computers'),
#   Interval(start=139.02038567963777, end=139.1411824446983, label='and'),
#   Interval(start=139.1411824446983, end=139.78780042237528, label='everything'),
#   Interval(start=140.61916639367425, end=140.7754916190467, label='and'),
#   Interval(start=140.7754916190467, end=140.98155668885585, label='bits'),
#   Interval(start=140.98155668885585, end=141.08103637772922, label='of'),
#   Interval(start=141.08103637772922, end=141.34394698403744, label='it'),
#   Interval(start=141.34394698403744, end=141.7205486633438, label='too'),
#   Interval(start=142.95584307025808, end=143.63798950824696, label='technical'),
#   Interval(start=143.63798950824696, end=144.01459118755335, label='really'),
#   Interval(start=147.00572052012478, end=147.19046851374677, label='other'),
#   Interval(start=147.19046851374677, end=147.34679373911922, label='than'),
#   Interval(start=147.34679373911922, end=147.75363788764258, label='that'),
#   Interval(start=148.26524771613424, end=148.64184939544063, label="stammered_it's"),
#   Interval(start=148.64184939544063, end=149.29557306517998, label='fine')]]

# %%
def getNextSuccess(my_list,iter):
    i = iter
    while(my_list[i]["case"] != "success"):
        i = i + 1
        
        if(i == len(my_list)):
            return "No Next"
        
    if (my_list[i]["case"] == "success"):
        return my_list[i]["alignedWord"]

def makeAdict(myString):
    new_dict = {}
    for i,word in enumerate(myString):
        new_dict[word] = [1,i]
    return new_dict

# def makeStringFromDict(mydict):
# 	for i in sorted(myDict.items(), key=lambda i: i[1][0], reverse=True):

def ManualTranscriptProcessing(google_transcript , real_transcript):
    Manual_answer = []
    #print(real_transcript)

    #print(google_transcript)
    for k in google_transcript:
        print(re.sub(r"[^a-zA-Z0-9]+", ' ', k))

    for k in real_transcript:
        print(re.sub(r"[^a-zA-Z0-9]+", ' ', k))

    # google_transcript_dict = makeAdict(google_transcript)
    # real_transcript_dict = makeAdict(real_transcript)
    google_transcript_list2 = [(i,word) for i,word in enumerate(list(google_transcript))]
    real_transcript_list2 = [(i,word) for i,word in enumerate(list(real_transcript))]
    real_transcript_lower = [x.lower() for x in real_transcript]
    google_transcript_lower = [x.lower() for x in google_transcript]
    for i in real_transcript_lower:
        if i in google_transcript_lower:
            google_transcript_lower.remove(i)
    print (google_transcript_lower)
    return google_transcript_lower

def startProcessing(filename , real_transcript):
    sound = AudioSegment.from_wav(filename)
    # obtain path to "english.wav" in the same folder as this script
    
    from os import path
    #AUDIO_FILE = path.join(path.dirname(path.realpath(__file__)), "output.wav")

    os.mkdir("new_data")
        
    # UNCOMMENT THIS LATER.......
    # file = open("transcript.txt","wr");
    # use the audio file as the audio source
    r = sr.Recognizer()
    
    with sr.AudioFile(filename) as source:
        audio = r.record(source)  # read the entire audio file
        
    print("read the audio...");
    file = open("transcript.txt", 'w');
    file.write(' '.join(real_transcript))
    file.close()

    # UNCOMMENT THIS LATER.......
    #recognize speech using Google Cloud Speech

    try:
        print("Google  Speech recognition results:")
        # file = open("transcript.txt", 'w');
        the_result = r.recognize_google(audio, language='en-UK',show_all =True)
        print(the_result)  # pretty-print the recognition result
        
    except sr.UnknownValueError:
        print("Google Cloud Speech could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Cloud Speech service; {0}".format(e))

    try:
        result = subprocess.Popen(['curl -F "audio=@output.wav" -F "transcript=@transcript.txt" "http://localhost:8765/transcriptions?async=false"'], stderr=subprocess.STDOUT, shell=True)
    except subprocess.CalledProcessError as e:
        raise RuntimeError("command '{}' return with error (code {}): {}".format(e.cmd, e.returncode, e.output))

    Manual_answer = ManualTranscriptProcessing(real_transcript,the_result)

    datastore = json.loads(result[0])
    words = datastore["words"]

    my_list = []

    not_found_in_audio = []


    for i in words:

        case = i["case"]

        if case == "success":

            alignedWord = i["alignedWord"]

            startTime = i["start"]*1000

            endTime = i["end"]*1000

            my_list.append({ "alignedWord" : alignedWord, "startTime" : startTime, "endTime": endTime, "case": case})

        elif(case == "not-found-in-transcript"):

            startTime = i["start"]*1000

            endTime = i["end"]*1000

            my_list.append({ "startTime" : startTime, "endTime": endTime, "case": case})

        else:
            not_found_in_audio.append(i["word"])


    my_list[0]["startTime"] = 0


    List_of_Audio_Words = []

    for i in my_list:

        if(i["case"] == "not-found-in-transcript"):

            List_of_Audio_Words.append([sound[i["startTime"] : i["endTime"]],1])

        else:
            List_of_Audio_Words.append([sound[i["startTime"] : i["endTime"]],0])


    List_of_files = []

    for i, chunk in enumerate(List_of_Audio_Words):

        filename = "new_data/chunk{0}"

        fail = "Failure"

        exten = ".wav"

        if(chunk[1] == 1):

            print("Found a Failure...")
            filename = filename + fail
            Final_name = filename + exten

        out_file = Final_name.format(i)
        print ("exporting", out_file)
        List_of_files.append(out_file)
        chunk[0].export(out_file, format="wav")

    print("Successfully chopped up all the files.")



    List_of_stutter_iter = []

    for i in List_of_files:
        if "Failure" in i:
            List_of_stutter_iter.append(int((re.findall('\d+', i))[0]))
            print (List_of_stutter_iter)



    List_of_stutter_words = []
    List_of_stutter_words += not_found_in_audio
    List_of_stutter_words += Manual_answer
    for i in List_of_stutter_iter:
        if (i != len(List_of_files)):
            ans = getNextSuccess(my_list,i)
            List_of_stutter_words.append(ans)
    shutil.rmtree("./new_data")
    return list(set(List_of_stutter_words))

# %%
transcript = outputList[1]
real_transcript = [label for _,_,label in transcript]
print(real_transcript)
# Out:
# ['errrm', 'as', 'we', 'start', 'start', 'our', 'first', 'thursday', 'we', 'went', 'ert', 'to', 'my', "nanny's", 'pause', 'cuz', 'my', 'parents', 'were', 'going', 'to', 'a', 'friends', 'stammered_wedding', 'and', 'then', 'we', 'went', 'home', 'on', 'saturday', 'we', "didnt't", 'do', 'much', 'we', 'just', 'they', "didn't", 'because', 'the', 'rained', 'pause', 'for', 'i think', 'cuz', "it's on", 'the', 'sunday', 'no', 'thursday', 'we', 'went', 'to', 'this', 'train', 'stammered_museum', 'pause', 'and it was', 'stammered_okay', 'but', 'it', 'was', 'bit', 'boring', 'and', 'and', 'then', 'cuz', 'when an', 'play', 'balls', 'we', 'went', 'and', 'that', 'paint', 'this', 'whole', 'for about', 'half', 'pause', 'very', 'exciting', 'and', 'then', 'sunday', 'pause', 'went', 'went', 'on', 'distinct', 'train', 'pause', 'and', 'back', 'we', 'we', 'it was okay', 'but', 'it', 'stammered', 'and', 'the', 'pause', 'and', 'the_prolonged', 'was', 'erm', 'floods', 'in the', 'nearby_stammered', 'pause', 'and', 'there', 'we', 'stayed', 'stayed in', 'and', 'one of', 'the', 'it was just', 'stayed_stammered', 'and then', 'play', 'games', 'and stuff', 'but', 'pause', 'the', 'day', 'that we', 'picked', 'up', 'we', 'went', 'down', 'to', 'to_stammered', 'this', 'em', 'park', 'and', 'we', 'had', 'a', 'walk', 'round', 'and', 'then', 'when', 'we', 'came', 'back', 'home', 'mum', 'and', 'dad', 'they were', 'here', 'to', 'take', 'us', 'home', 'and', 'so', 'and', 'so', 'pause', 'at', 'school', 'lost', 'and', 'we', 'did', 'about', 'you', 'stammered_village', 'whcih', 'is', 'close', 'by', 'and', 'one', 'day', 'we', 'went']

# %%
startProcessing('AllAudioWav/F_0050_10y9m_1.wav' , real_transcript)
# Out:
# read the audio...
# Google  Speech recognition results:
# {'alternative': [{'transcript': "star first Thursday we went into mine and cuz my parents wouldn't to a friend's wedding and we went home on Saturday we didn't do much we just say them because it rains but I think was on the Sunday night that day we went to this train museum it was ok but it was a bit boring and and then cuz when only one that play bowls and we went and sat in this hole for about half-an-hour boys and play bowls very exciting and then on Sunday we went on the steam train and back was ok but it was a bit of a frozen ice and that store was floods and nearby and so we stayed in and one afternoon clip for Saturday 12 Bridges staging and play games and stuff but on the day that we been picked up we went down to do this and we had a walk around and then when we came back our mum and dad were here to take us home and cool last time we did about your village which is close by and when David went", 'confidence': 0.91379333}, {'transcript': "star first Thursday we went into mine and cuz my parents wouldn't to a friend's wedding and we went home on Saturday we didn't do much we just say them because it rains but I think was on the Sunday night that day we went to this train museum it was ok but it was a bit boring and and then cuz when only one that play bowls and we went and sat in this hole for about half-an-hour boys and play bowls very exciting and then on Sunday we went on the steam train and back was ok but it was a bit of a frozen ice and that stuff is floods and nearby and so we stayed in and one afternoon clip for Saturday 12 Bridges staging and play games and stuff but on the day that we been picked up we went down to do this and we had a walk around and then when we came back our mum and dad were here to take us home and cool last time we did about your village which is close by and when David went"}, {'transcript': "star first Thursday we went into mine and cuz my parents wouldn't to a friend's wedding and we went home on Saturday we didn't do much we just say them because it rains but I think was on the Sunday night that day we went to this train museum it was ok but it was a bit boring and and then cuz when only when did play bowls and we went and sat in this hole for about half-an-hour boys and play bowls very exciting and then on Sunday we went on the steam train and back was ok but it was a bit of a frozen ice and that store was floods and nearby and so we stayed in and one afternoon clip for Saturday 12 Bridges staging and play games and stuff but on the day that we been picked up we went down to do this and we had a walk around and then when we came back our mum and dad were here to take us home and cool last time we did about your village which is close by and when David went"}, {'transcript': "star first Thursday we went into mine and cuz my parents wouldn't to a friend's wedding and we went home on Saturday we didn't do much we just say them because it rains but I think was on the Sunday night that day we went to this train museum it was ok but it was a bit boring and and then cuz when only one that play bowls and we went and sat in this hole for about half-an-hour boys and play bowls very exciting and then on Sunday we went on the steam train and back was ok but it was a bit of a frozen ice and that store was floods and nearby and so we stayed in and one afternoon clip for Saturday 12 Bridges staging and play games and stuff but on the day that we been picked up we went down to to this park and we had a walk around and then when we came back our mum and dad were here to take us home and cool last time we did about your village which is close by and when David went"}, {'transcript': "star first Thursday we went into mine and cuz my parents wouldn't to a friend's wedding and we went home on Saturday we didn't do much we just say them because it rains but I think was on the Sunday night that day we went to this train museum it was ok but it was a bit boring and and then cuz when only when did play bow ...
# errrm
# as
# we
# start
# start
# our
# first
# thursday
# we
# went
# ert
# to
# my
# nanny s
# pause
# cuz
# my
# parents
# were
# going
# to
# a
# friends
# stammered wedding
# and
# then
# we
# went
# home
# on
# saturday
# we
# didnt t
# do
# much
# we
# just
# they
# didn t
# because
# the
# rained
# pause
# for
# i think
# cuz
# it s on
# the
# sunday
# no
# thursday
# we
# went
# to
# this
# train
# stammered museum
# pause
# and it was
# stammered okay
# but
# it
# was
# bit
# boring
# and
# and
# then
# cuz
# when an
# play
# balls
# we
# went
# and
# that
# paint
# this
# whole
# for about
# half
# pause
# very
# exciting
# and
# then
# sunday
# pause
# went
# went
# on
# distinct
# train
# pause
# and
# back
# we
# we
# it was okay
# but
# it
# stammered
# and
# the
# pause
# and
# the prolonged
# was
# erm
# floods
# in the
# nearby stammered
# pause
# and
# there
# we
# stayed
# stayed in
# and
# one of
# the
# it was just
# stayed stammered
# and then
# play
# games
# and stuff
# but
# pause
# the
# day
# that we
# picked
# up
# we
# went
# down
# to
# to stammered
# this
# em
# park
# and
# we
# had
# a
# walk
# round
# and
# then
# when
# we
# came
# back
# home
# mum
# and
# dad
# they were
# here
# to
# take
# us
# home
# and
# so
# and
# so
# pause
# at
# school
# lost
# and
# we
# did
# about
# you
# stammered village
# whcih
# is
# close
# by
# and
# one
# day
# we
# went
# alternative
# final
# ['errrm', 'as', 'we', 'start', 'start', 'our', 'first', 'thursday', 'we', 'went', 'ert', 'to', 'my', "nanny's", 'pause', 'cuz', 'my', 'parents', 'were', 'going', 'to', 'a', 'friends', 'stammered_wedding', 'and', 'then', 'we', 'went', 'home', 'on', 'saturday', 'we', "didnt't", 'do', 'much', 'we', 'just', 'they', "didn't", 'because', 'the', 'rained', 'pause', 'for', 'i think', 'cuz', "it's on", 'the', 'sunday', 'no', 'thursday', 'we', 'went', 'to', 'this', 'train', 'stammered_museum', 'pause', 'and it was', 'stammered_okay', 'but', 'it', 'was', 'bit', 'boring', 'and', 'and', 'then', 'cuz', 'when an', 'play', 'balls', 'we', 'went', 'and', 'that', 'paint', 'this', 'whole', 'for about', 'half', 'pause', 'very', 'exciting', 'and', 'then', 'sunday', 'pause', 'went', 'went', 'on', 'distinct', 'train', 'pause', 'and', 'back', 'we', 'we', 'it was okay', 'but', 'it', 'stammered', 'and', 'the', 'pause', 'and', 'the_prolonged', 'was', 'erm', 'floods', 'in the', 'nearby_stammered', 'pause', 'and', 'there', 'we', 'stayed', 'stayed in', 'and', 'one of', 'the', 'it was just', 'stayed_stammered', 'and then', 'play', 'games', 'and stuff', 'but', 'pause', 'the', 'day', 'that we', 'picked', 'up', 'we', 'went', 'down', 'to', 'to_stammered', 'this', 'em', 'park', 'and', 'we', 'had', 'a', 'walk', 'round', 'and', 'then', 'when', 'we', 'came', 'back', 'home', 'mum', 'and', 'dad', 'they were', 'here', 'to', 'take', 'us', 'home', 'and', 'so', 'and', 'so', 'pause', 'at', 'school', 'lost', 'and', 'we', 'did', 'about', 'you', 'stammered_village', 'whcih', 'is', 'close', 'by', 'and', 'one', 'day', 'we', 'went']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-baa33e444151> in <module>
# ----> 1 startProcessing('AllAudioWav/F_0050_10y9m_1.wav' , real_transcript)
#
# <ipython-input-43-7ac76ddddb78> in startProcessing(filename, real_transcript)
#      87     Manual_answer = ManualTranscriptProcessing(real_transcript,the_result)
#      88
# ---> 89     datastore = json.loads(result)
#      90
#      91     print(result)
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     516             parse_constant is None and object_pairs_hook is None
#     517             and not use_decimal and not kw):
# --> 518         return _default_decoder.decode(s)
#     519     if cls is None:
#     520         cls = JSONDecoder
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/simplejson/decoder.py in decode(self, s, _w, _PY3)
#     368         if _PY3 and isinstance(s, bytes):
#     369             s = str(s, self.encoding)
# --> 370         obj, end = self.raw_decode(s)
#     371         end = _w(s, end).end()
#     372         if end != len(s):
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/simplejson/decoder.py in raw_decode(self, s, idx, _w, _PY3)
#     390             raise JSONDecodeError('Expecting value', s, idx)
#     391         if _PY3 and not isinstance(s, str):
# --> 392             raise TypeError("Input string must be text, not bytes")
#     393         # strip UTF-8 bom
#     394         if len(s) > idx:
#
# TypeError: Input string must be text, not bytes
